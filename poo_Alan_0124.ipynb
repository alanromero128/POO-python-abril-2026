# %% [markdown]
# <a href="https://colab.research.google.com/github/alanromero128/POO-python-abril-2026/blob/main/poo_Alan_0124.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Alan Romero NL =  47  fecha:21/Abril/2926
# ### Conceptos de POO (Programacion orientada a objetos) en python

# %% [markdown]
# ### El promp en IA gemini
# lenguaje Python, crear la clase "animal" con los atributos "nombre" , "raza" crear el conductor animal, y las funciones ladrar(),correr(),crear los objetos pitbull, Chihuahua, nivel principiantes, no es interactivo

# %%
# Definición de la clase
class Animal:
    # El constructor (__init__) inicializa los atributos del objeto
    def __init__(self, nombre, raza):
        self.nombre = nombre
        self.raza = raza

    # Función o método para ladrar
    def ladrar(self):
        print(f"{self.nombre} dice: ¡Guau, guau!🔺")

    # Función o método para correr
    def correr(self):
        print(f"{self.nombre} está corriendo velozmente.⚽")

    def Morder( self):
        print(f"{self.nombre} está mordiendo a la vecina🏅")

# Creación de los objetos (Instancias)

# 1. Objeto Pitbull
pitbull = Animal("Zeus", "Pitbull")

# 2. Objeto Chihuahua
chihuahua = Animal("Chispa", "Chihuahua")
# creamos el objeto perro callejero con datos
perrocallejero = Animal("solovino","chafa")
# Uso de los objetos
print(f"Perro 1: {pitbull.nombre}, Raza: {pitbull.raza}")
pitbull.ladrar()
pitbull.correr()
pitbull.Morder()
print("-" * 20)

print(f"Perro 2: {chihuahua.nombre}, Raza: {chihuahua.raza}")
chihuahua.ladrar()
chihuahua.correr()
chihuahua.Morder()
print("-" * 20)
print(f"Perro 3: {perrocallejero.nombre}, Raza: {perrocallejero.raza}")
perrocallejero.ladrar()
perrocallejero.correr()
perrocallejero.Morder()
print("-" * 20)
print("Programa creado por Alan Romero  NL = 47")
# Out:
# Perro 1: Zeus, Raza: Pitbull
# Zeus dice: ¡Guau, guau!🔺
# Zeus está corriendo velozmente.⚽
# Zeus está mordiendo a la vecina🏅
# --------------------
# Perro 2: Chispa, Raza: Chihuahua
# Chispa dice: ¡Guau, guau!🔺
# Chispa está corriendo velozmente.⚽
# Chispa está mordiendo a la vecina🏅
# --------------------
# Perro 3: solovino, Raza: chafa
# solovino dice: ¡Guau, guau!🔺
# solovino está corriendo velozmente.⚽
# solovino está mordiendo a la vecina🏅
# --------------------
# Programa creado por Alan Romero  NL = 47
